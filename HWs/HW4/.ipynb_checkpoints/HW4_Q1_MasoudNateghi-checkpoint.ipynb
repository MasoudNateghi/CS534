# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from scipy.stats import pearsonr, kendalltau, spearmanr
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, precision_score, recall_score, fbeta_score

# %%
# file path
csv_file_path = "loan_default.csv"

# load file
df = pd.read_csv(csv_file_path, dtype={'MyColumn': 'str'})

# %%
# preprocessing
# remove months from term column and convert numbers 36 and 60 to integers
df['term'] = df['term'].str.extract('(\d+)').astype(int)

# encode grade column
grade_mapping = {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'F': 6, 'G': 7}

# apply the mapping
df['grade'] = df['grade'].map(grade_mapping)

# encode emp_length column
emp_length_mapping = {'< 1 year': 1, '1 year': 2, '2 years': 3, '3 years': 4, '4 years': 5, '5 years': 6,
                      '6 years': 7, '7 years': 8, '8 years': 9, '9 years': 10, '10+ years': 11}
# apply the mapping
df['emp_length'] = df['emp_length'].map(emp_length_mapping)

# fill NaN values of emp_length column
df['emp_length'].fillna(0, inplace=True)

# count number of months for each earliest credit line entry up to Dec 2011
def count_months(start, end):
    start_date = datetime.strptime(start, '%b-%y')
    end_date = datetime.strptime(end, '%b-%y')
    months = (end_date.year - start_date.year) * 12 + end_date.month - start_date.month
    return months

# Calculate the number of months for each entry
df['earliest_cr_line'] = df.apply(lambda row: count_months(row['earliest_cr_line'], 'Dec-11'), axis=1)

# Use one-hot encoding for home_ownership, verification_status, purpose columns
# supress warnings
import warnings
warnings.filterwarnings('ignore')

# Create an instance of OneHotEncoder
encoder = OneHotEncoder(sparse=False)

# Fit the encoder on the categorical column and transform it
encoded_data = encoder.fit_transform(df[['home_ownership', 'verification_status', 'purpose']])

# Create a new DataFrame with one-hot encoded columns
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(['home_ownership', 'verification_status', 'purpose']))

# remove irrelevant features
df = df.drop(columns=['id'])

# remove redundant categorical features
df = df.drop(columns=['home_ownership', 'verification_status', 'purpose'])

# extract lables from dataset and remove 'class' column
labels = df['class'].values
df = df.drop('class', axis=1)

# concat encoded dataframe with original dataframe
data = pd.concat([df, encoded_df], axis=1).to_numpy()

# %%
# split data into train and test 
trainx, testx, trainy, testy = train_test_split(data, labels, test_size=0.2, random_state=42)

# normaliztion
scaler = StandardScaler()
trainx = scaler.fit_transform(trainx)
# Transform the testing data based on the fitted scaler
testx = scaler.transform(testx)

# %%
def compute_correlation(x, corrtype):
    # number of features
    n_features = x.shape[1]
    
    # create correlation matrix
    corr = np.zeros((n_features, n_features))
    
    if corrtype == 'pearson':
        for i in range(n_features):
            for j in range(n_features):
                corr[i, j], _ = pearsonr(x[:, i], x[:, j])
    elif corrtype == 'kendall':
        for i in range(n_features):
            for j in range(n_features):
                corr[i, j], _ = kendalltau(x[:, i], x[:, j])
    elif corrtype == 'spearman':
        for i in range(n_features):
            for j in range(n_features):
                corr[i, j], _ = spearmanr(x[:, i], x[:, j])
                
    return corr

# Pearson
corr = compute_correlation(trainx, 'pearson')
plt.figure(figsize=(8, 8))
sns.heatmap(corr, annot=False, cmap='coolwarm', square=True)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
columns_to_remove = [0, 2, 6, 10, 12, 19, 21, 26, 28]

# Remove the specified columns
trainx = np.delete(trainx, columns_to_remove, axis=1)
testx = np.delete(testx, columns_to_remove, axis=1)

# %%
# rank correlation
# number of features
n_features = trainx.shape[1]

# create correlation vector
corr = np.zeros(n_features)

for i in range(n_features):
    corr[i], _ = pearsonr(trainx[:, i], trainy)

# calculate absolute values
# corr = abs(corr)
print(corr)

# We take k to be 25!
# Out:
# [ 0.15607183  0.01968187  0.26459172 -0.05273085  0.16757451  0.03439004
#  -0.06193702 -0.0031393  -0.03208417  0.10968028 -0.04962906  0.44768437
#  -0.0052745   0.02011764 -0.07174047 -0.04456662 -0.02987228  0.06270531
#  -0.079648    0.07906505 -0.0102005   0.04017201 -0.0812016  -0.01747612
#  -0.02104784  0.02746644 -0.01482373  0.01349266 -0.01931669  0.05493955
#   0.00557885 -0.01006764]

# %%
def rank_correlation(x, y):
    # number of features
    n_features = x.shape[1]
    
    # create correlation vector
    corr = np.zeros(n_features)
    
    for i in range(n_features):
        corr[i], _ = pearsonr(x[:, i], y)
        
    # calculate absolute values
    corr = abs(corr)
    
    # find indices in descending order
    sorted_indices = np.argsort(corr)[::-1]
    
    return sorted_indices

# select features form rank correlation function
k = 25
selected_columns = rank_correlation(trainx, trainy)[:k]
trainx = trainx[:, selected_columns]
testx = testx[:, selected_columns]

# %%
# use PCA to whiten data
# Initialize PCA
pca = PCA(whiten=True)

# Fit and transform the train data
trainx = pca.fit_transform(trainx)

# Transform the test data
testx = pca.transform(testx)

# %%
def tune_nn(x, y, hiddenparams, actparams, alphaparams):
    # solvers = 'lbfgs', 'sgd', 'adam
    # lr = 'constant', 'adaptive'
    # warm_start=True
    # create MLP model
    model = MLPClassifier(max_iter=100, solver='adam', learning_rate='adaptive')
    
    # Define the hyperparameter grid to search
    param_grid = {
        'hidden_layer_sizes': hiddenparams,  
        'activation': actparams, 
        'alpha': alphaparams, 
    }
    
    # Create a GridSearchCV object
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='roc_auc', verbose=2)
    
    # Perform grid search with cross-validation
    grid_search.fit(x, y)
    
    # Get the best hyperparameters
    best_hidden = grid_search.best_params_['hidden_layer_sizes']
    best_activation = grid_search.best_params_['activation']
    best_alpha = grid_search.best_params_['alpha']
    best_score = grid_search.best_score_
    
    # Access the cross-validation results
    cv_results = grid_search.cv_results_
    
    return {'best-hidden': best_hidden, 'best-activation': best_activation, 'best-alpha': best_alpha, 
            'best-valid-AUC': best_score, 'grid_search': grid_search}

# %%
hidden_size = [(10, 30, 10), (100, 50), (40, 20), (20, ), (40, )]
activation = ['relu', 'logistic', 'tanh']
alpha = [0.001, 0.01, 0.1, 1, 10]
result = tune_nn(trainx, trainy, hidden_size, activation, alpha)
# Out:
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 30, 10); total time=   0.8s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 30, 10); total time=   0.7s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 30, 10); total time=   0.8s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 30, 10); total time=   0.7s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50); total time=   1.2s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50); total time=   1.3s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50); total time=   1.2s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50); total time=   1.2s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50); total time=   1.2s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(40, 20); total time=   0.7s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(40, 20); total time=   1.1s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(40, 20); total time=   1.1s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(40, 20); total time=   1.1s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(40, 20); total time=   1.1s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20,); total time=   0.7s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(100, 50); total time=   1.4s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(100, 50); total time=   1.4s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(40, 20); total time=   1.0s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(40, 20); total time=   1.0s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(40, 20); total time=   1.0s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(40, 20); total time=   1.0s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20,); total time=   0.4s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20,); total time=   0.4s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(40,); total time=   0.5s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(10, 30, 10); total time=   1.1s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(100, 50); total time=   1.4s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(100, 50); total time=   1.4s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(100, 50); total time=   1.4s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(40, 20); total time=   1.0s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=0.1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(10, 30, 10); total time=   1.2s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(100, 50); total time=   1.4s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(100, 50); total time=   1.4s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(100, 50); total time=   1.4s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(40, 20); total time=   0.8s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(40, 20); total time=   0.8s
# [CV] END activation=relu, alpha=1, hidden_layer_sizes=(40, 20); total time=   0.8s
# [CV] END .activation=relu, alpha=1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END .activation=relu, alpha=1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END .activation=relu, alpha=1, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END .activation=relu, alpha=1, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END .activation=relu, alpha=1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END .activation=relu, alpha=1, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END .activation=relu, alpha=1, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END .activation=relu, alpha=1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END .activation=relu, alpha=1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END .activation=relu, alpha=1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(10, 30, 10); total time=   0.8s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(100, 50); total time=   1.1s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(100, 50); total time=   1.3s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(100, 50); total time=   1.4s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(100, 50); total time=   1.0s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(100, 50); total time=   1.3s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(40, 20); total time=   0.8s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(40, 20); total time=   0.8s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(40, 20); total time=   0.8s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(20,); total time=   0.4s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(20,); total time=   0.4s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(20,); total time=   0.4s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(40,); total time=   0.5s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=relu, alpha=10, hidden_layer_sizes=(40,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50); total time=   1.8s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50); total time=   1.7s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50); total time=   1.6s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50); total time=   1.6s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(40, 20); total time=   0.8s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(40,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(10, 30, 10); total time=   1.1s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(10, 30, 10); total time=   1.1s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50); total time=   1.7s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50); total time=   1.8s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50); total time=   1.8s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(40, 20); total time=   1.1s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(40, 20); total time=   1.0s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(40,); total time=   0.8s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(10, 30, 10); total time=   0.9s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(10, 30, 10); total time=   1.1s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(10, 30, 10); total time=   1.1s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(100, 50); total time=   1.8s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(100, 50); total time=   1.7s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(100, 50); total time=   1.7s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(100, 50); total time=   1.7s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(100, 50); total time=   1.9s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(40, 20); total time=   1.0s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=logistic, alpha=0.1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(10, 30, 10); total time=   0.6s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(10, 30, 10); total time=   0.7s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(10, 30, 10); total time=   0.7s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(10, 30, 10); total time=   0.7s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(100, 50); total time=   1.6s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(100, 50); total time=   1.6s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(100, 50); total time=   1.6s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(40, 20); total time=   0.8s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(40, 20); total time=   0.9s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(20,); total time=   0.5s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(20,); total time=   0.7s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(20,); total time=   0.6s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(40,); total time=   0.7s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(40,); total time=   0.6s
# [CV] END activation=logistic, alpha=1, hidden_layer_sizes=(40,); total time=   0.8s
# [CV] END activation=logistic, alpha=10, hidden_layer_sizes=(10, 30, 10); total time=   1.1s
# [CV] END activation=logistic, alpha=10, hidden_layer_sizes=(10, 30, 10); total time=   1.1s
# [CV] END activation=logistic, alpha=10, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=logistic, alpha=10, hidden_layer_sizes=(10, 30, 10); total time=   0.8s
# [CV] END activation=logistic, alpha=10, hidden_layer_sizes=(10, 30, 10); total time=   1.0s
# [CV] END activation=logistic, alpha=10, hidden_layer_sizes=(100, 50); total time=   1.5s
# [CV] END activation=logistic, alpha=10, hidden_layer_sizes=(100, 50); total time=   1.4s
# [CV] END activation=logistic, alpha=10, hidden_layer_sizes=(100, 50); total time=   1.2s
# [CV] END activation=logistic, alpha=10, hidden_layer_sizes=(100, 50); total time=   1.4s

# %%
result

# %%
import time
start_time = time.time()
# train MLP using best parameters
# Create a Decision Tree classifier
model = MLPClassifier(hidden_layer_sizes=(100, 50), activation='logistic', alpha=0.01, 
                      max_iter=100, solver='adam', learning_rate='adaptive')

# train model
model.fit(trainx, trainy)

# make prediction on test data
testy_pred = model.predict(testx)
trainy_pred = model.predict(trainx)

# Calculate AUC, F1-score, F2-score
test_auc_score = roc_auc_score(testy, testy_pred) #AUC
train_auc_score = roc_auc_score(trainy, trainy_pred) #AUC
test_f1 = f1_score(testy, testy_pred) # F1-score
train_f1 = f1_score(trainy, trainy_pred) # F1-score
test_f2 = fbeta_score(testy, testy_pred, beta=2) #F2-score
train_f2 = fbeta_score(trainy,trainy_pred, beta=2) #F2-score
duration = time.time() - start_time

print('test AUC: ', test_auc_score)
print('test F1-score: ', test_f1)
print('test F2-score: ', test_f2)
print('-----------------------------')
print('train AUC: ', train_auc_score)
print('train F1-score: ', train_f1)
print('train F2-score: ', train_f2)
print('runtime: ', duration)
