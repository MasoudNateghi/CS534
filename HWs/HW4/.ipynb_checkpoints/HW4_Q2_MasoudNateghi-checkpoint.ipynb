# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.base import RegressorMixin
from sklearn.tree import DecisionTreeRegressor

# %%
csv_file_path_train = 'energy_train.csv'
csv_file_path_val   = 'energy_val.csv'
csv_file_path_test  = 'energy_test.csv'

# Read the CSV file into a Pandas DataFrame
df_train = pd.read_csv(csv_file_path_train)
df_val   = pd.read_csv(csv_file_path_val  )
df_test  = pd.read_csv(csv_file_path_test )

# %%
df_train.head()
# Out:
#             date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  1/11/16 17:00          60      30  19.89  47.596667  19.2  44.790000
# 1  1/11/16 17:10          60      30  19.89  46.693333  19.2  44.722500
# 2  1/11/16 17:20          50      30  19.89  46.300000  19.2  44.626667
# 3  1/11/16 17:30          50      40  19.89  46.066667  19.2  44.590000
# 4  1/11/16 17:40          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...    T8       RH_8         T9   RH_9  T_out  \
# 0  19.79  44.730000  19.000000  ...  18.2  48.900000  17.033333  45.53   6.60
# 1  19.79  44.790000  19.000000  ...  18.2  48.863333  17.066667  45.56   6.48
# 2  19.79  44.933333  18.926667  ...  18.2  48.730000  17.000000  45.50   6.37
# 3  19.79  45.000000  18.890000  ...  18.1  48.590000  17.000000  45.40   6.25
# 4  19.79  45.000000  18.890000  ...  18.1  48.590000  17.000000  45.40   6.13
#
#    Press_mm_hg  RH_out  Windspeed  Visibility  Tdewpoint
# 0        733.5    92.0   7.000000   63.000000        5.3
# 1        733.6    92.0   6.666667   59.166667        5.2
# 2        733.7    92.0   6.333333   55.333333        5.1
# 3        733.8    92.0   6.000000   51.500000        5.0
# 4        733.9    92.0   5.666667   47.666667        4.9
#
# [5 rows x 27 columns]

# %%
def feature_extraction(df, normalization='z-score'):
    import warnings
    warnings.filterwarnings('ignore')
    df['date'] = pd.to_datetime(df['date'])
    
    # Extract the day of the week and create a new column
    df['DayOfWeek'] = df['date'].dt.day_name()
    
    # Create a new column for 2-hour intervals
    df['TimeInterval'] = df['date'].dt.strftime('%H:%M:%S').str[:2].astype(int) // 2 * 2
    
    # Encode 'TimeInterval' using one-hot encoding
    df['TimeInterval'] = df['TimeInterval'].astype(str)
    
    # import OneHotEncoder
    from sklearn.preprocessing import OneHotEncoder
    
    # Create an instance of OneHotEncoder
    encoder = OneHotEncoder(sparse=False)
    
    # Fit the encoder on the categorical column and transform it
    encoded_data = encoder.fit_transform(df[['DayOfWeek', 'TimeInterval']])
    
    # Create a new DataFrame with one-hot encoded columns
    encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(['DayOfWeek', 'TimeInterval']))
    y = np.reshape(df['Appliances'].to_numpy(), (-1, 1))
    
    # Drop the original 'Category' column
    df.drop(columns=['DayOfWeek', 'TimeInterval', 'date', 'Appliances'], inplace=True)
    
    # Concatenate the one-hot encoded DataFrame with the original DataFrame
    X = pd.concat([df, encoded_df], axis=1).to_numpy()
    
    return X, y

# %%
# preprocess data
trainx, trainy = feature_extraction(df_train)
valx , valy = feature_extraction(df_val)
testx, testy = feature_extraction(df_test)

# normaliztion
scaler = StandardScaler()
trainx = scaler.fit_transform(trainx)
# Transform the testing data based on the fitted scaler
valx = scaler.transform(valx)
testx = scaler.transform(testx)

# flatten y to be 1D numpy array
trainy = trainy.flatten()
valy = valy.flatten()
testy = testy.flatten()

# %%
trainx.shape
# Out:
# (9868, 44)

# %%
def tune_sgtb(x, y, lst_nIter, lst_nu, lst_q, md):
    # create SGTB model
    model = SGTB(md=md)
    
    # Define the hyperparameter grid to search
    param_grid = {
        'nIter': lst_nIter,  
        'q': lst_q, 
        'nu': lst_nu, 
    }
    
    # Create a GridSearchCV object
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_root_mean_squared_error', verbose=2)
    
    # Perform grid search with cross-validation
    grid_search.fit(x, y)
    
    # Get the best hyperparameters
    best_nIter = grid_search.best_params_['nIter']
    best_q = grid_search.best_params_['q']
    best_nu = grid_search.best_params_['nu']
    best_score = grid_search.best_score_
    
    return {'best-nIter': best_nIter, 'best-nu': best_nu, 'best-q': best_q, 
            'best-RMSE': best_score, 'grid_search': grid_search}


def compute_residual(y_true, y_pred):
    return y_true - y_pred


class SGTB(RegressorMixin):
    def __init__(self, nIter=1, q=1, nu=0.1, md=3):
        self.nIter = nIter # number of boosting iterations
        self.q = q # subsampling rate
        self.nu = nu # shrinkage parameter
        self.md = md # max depth of the tree that is trained at each iteration
        # key is the iteration and the value is the RMSE of the training data. Note that for the 0th iteration,
        # it should return the RMSE for a model that predicts the mean of y and the 1st iteration would return
        # the RMSE for a single tree fit to the initial set of residuals multiplied by the shrinkage rate.
        self.train_dict = {} 

    def get_params(self, deep=True):
        return {"nIter": self.nIter,
                "q": self.q,
                "nu": self.nu,
                "md": self.md}

    # set the parameters
    def set_params(self, **parameters):
        for parameter, value in parameters.items():
            setattr(self, parameter, value)
        return self

    # train data using gradient boosting
    def fit(self, x, y):
        # to store h_m at m-th iteration
        self.model = []
        # target mean
        f_0 = np.mean(y)
        # add f_0 to models
        self.model.append(f_0)
        # calculate RMSE at 0th iteration
        y_pred = self.model[0] * np.ones(x.shape[0])
        self.train_dict[0] = mean_squared_error(y, y_pred, squared=False)
        
        for m in range(1, self.nIter + 1):
            # size of subsampled dataset
            n = int(x.shape[0] * self.q)
            # indices to be selected from dataset
            idx = np.random.choice(x.shape[0], n, replace=False)
            # retrive subsampled data
            x_sub = x[idx, :]
            y_sub = y[idx]
            # make prediction on x_sub to calculate residuals
            y_sub_pred = self.model[0] * np.ones(n)
            for i in range(1, m):
                # calculate similar to line 6 of Alg1
                y_sub_pred += self.nu * self.model[i].predict(x_sub)
            # calculate residuals
            r_m = compute_residual(y_sub, y_sub_pred)
            # instantiate decision tree regressor model
            h_m = DecisionTreeRegressor(max_depth=self.md)
            # train h_m
            h_m.fit(x_sub, r_m)
            # add h_m to the list of models
            self.model.append(h_m)
            # update self.train_dict
            y_sub_pred += self.nu * self.model[m].predict(x_sub)
            self.train_dict[m] = mean_squared_error(y_sub, y_sub_pred, squared=False)

    def predict(self, x):
        # number of samples
        n_sample = x.shape[0]
        # build the output
        y = self.model[0] * np.ones(n_sample)
        
        for i in range(1, self.nIter):
            # retrieve h_m form list of models
            h_m = self.model[i]
            # predict on data
            y += self.nu * h_m.predict(x)
        
        return y

# %%
lst_nIter = [1, 10, 20, 30]
lst_nu = [0.1, 0.2, 0.3]
lst_q = [0.6, 0.7, 0.8, 0.9, 1]
md = 3

result = tune_sgtb(trainx, trainy, lst_nIter, lst_nu, lst_q, 3)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] END .............................nIter=1, nu=0.1, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.1, q=0.9; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.1, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.1, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.1, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.1, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.1, q=1; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.2, q=0.9; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.2, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.2, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.2, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.2, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.2, q=1; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.6; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.7; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.8; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.9; total time=   0.0s
# [CV] END .............................nIter=1, nu=0.3, q=0.9; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.3, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.3, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.3, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.3, q=1; total time=   0.0s
# [CV] END ...............................nIter=1, nu=0.3, q=1; total time=   0.0s
# [CV] END ............................nIter=10, nu=0.1, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.1, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.1, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.1, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.1, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.1, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.1, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.1, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.1, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.1, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.1, q=0.8; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.1, q=0.8; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.1, q=0.8; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.1, q=0.8; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.1, q=0.8; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.1, q=0.9; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.1, q=0.9; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.1, q=0.9; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.1, q=0.9; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.1, q=0.9; total time=   0.2s
# [CV] END ..............................nIter=10, nu=0.1, q=1; total time=   0.2s
# [CV] END ..............................nIter=10, nu=0.1, q=1; total time=   0.3s
# [CV] END ..............................nIter=10, nu=0.1, q=1; total time=   0.3s
# [CV] END ..............................nIter=10, nu=0.1, q=1; total time=   0.3s
# [CV] END ..............................nIter=10, nu=0.1, q=1; total time=   0.4s
# [CV] END ............................nIter=10, nu=0.2, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.2, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.2, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.2, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.2, q=0.6; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.2, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.2, q=0.7; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.2, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.2, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.2, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.2, q=0.8; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.2, q=0.8; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.2, q=0.8; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.2, q=0.8; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.2, q=0.8; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.2, q=0.9; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.2, q=0.9; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.2, q=0.9; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.2, q=0.9; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.2, q=0.9; total time=   0.3s
# [CV] END ..............................nIter=10, nu=0.2, q=1; total time=   0.4s
# [CV] END ..............................nIter=10, nu=0.2, q=1; total time=   0.5s
# [CV] END ..............................nIter=10, nu=0.2, q=1; total time=   0.5s
# [CV] END ..............................nIter=10, nu=0.2, q=1; total time=   0.5s
# [CV] END ..............................nIter=10, nu=0.2, q=1; total time=   0.4s
# [CV] END ............................nIter=10, nu=0.3, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.3, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.3, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.3, q=0.6; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.3, q=0.6; total time=   0.1s
# [CV] END ............................nIter=10, nu=0.3, q=0.7; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.3, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.3, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.3, q=0.7; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.3, q=0.7; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.3, q=0.8; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.3, q=0.8; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.3, q=0.8; total time=   0.2s
# [CV] END ............................nIter=10, nu=0.3, q=0.8; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.3, q=0.8; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.3, q=0.9; total time=   0.4s
# [CV] END ............................nIter=10, nu=0.3, q=0.9; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.3, q=0.9; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.3, q=0.9; total time=   0.3s
# [CV] END ............................nIter=10, nu=0.3, q=0.9; total time=   0.3s
# [CV] END ..............................nIter=10, nu=0.3, q=1; total time=   0.4s
# [CV] END ..............................nIter=10, nu=0.3, q=1; total time=   0.4s
# [CV] END ..............................nIter=10, nu=0.3, q=1; total time=   0.4s
# [CV] END ..............................nIter=10, nu=0.3, q=1; total time=   0.4s
# [CV] END ..............................nIter=10, nu=0.3, q=1; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.1, q=0.6; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.1, q=0.6; total time=   0.8s
# [CV] END ............................nIter=20, nu=0.1, q=0.6; total time=   0.7s
# [CV] END ............................nIter=20, nu=0.1, q=0.6; total time=   0.7s
# [CV] END ............................nIter=20, nu=0.1, q=0.6; total time=   0.8s
# [CV] END ............................nIter=20, nu=0.1, q=0.7; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.1, q=0.7; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.1, q=0.7; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.1, q=0.7; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.1, q=0.7; total time=   1.0s
# [CV] END ............................nIter=20, nu=0.1, q=0.8; total time=   0.7s
# [CV] END ............................nIter=20, nu=0.1, q=0.8; total time=   0.7s
# [CV] END ............................nIter=20, nu=0.1, q=0.8; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.1, q=0.8; total time=   0.8s
# [CV] END ............................nIter=20, nu=0.1, q=0.8; total time=   0.8s
# [CV] END ............................nIter=20, nu=0.1, q=0.9; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.1, q=0.9; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.1, q=0.9; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.1, q=0.9; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.1, q=0.9; total time=   0.9s
# [CV] END ..............................nIter=20, nu=0.1, q=1; total time=   1.0s
# [CV] END ..............................nIter=20, nu=0.1, q=1; total time=   1.0s
# [CV] END ..............................nIter=20, nu=0.1, q=1; total time=   1.0s
# [CV] END ..............................nIter=20, nu=0.1, q=1; total time=   0.9s
# [CV] END ..............................nIter=20, nu=0.1, q=1; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.2, q=0.6; total time=   0.5s
# [CV] END ............................nIter=20, nu=0.2, q=0.6; total time=   0.5s
# [CV] END ............................nIter=20, nu=0.2, q=0.6; total time=   0.5s
# [CV] END ............................nIter=20, nu=0.2, q=0.6; total time=   0.5s
# [CV] END ............................nIter=20, nu=0.2, q=0.6; total time=   0.5s
# [CV] END ............................nIter=20, nu=0.2, q=0.7; total time=   0.6s
# [CV] END ............................nIter=20, nu=0.2, q=0.7; total time=   0.5s
# [CV] END ............................nIter=20, nu=0.2, q=0.7; total time=   0.6s
# [CV] END ............................nIter=20, nu=0.2, q=0.7; total time=   0.6s
# [CV] END ............................nIter=20, nu=0.2, q=0.7; total time=   0.6s
# [CV] END ............................nIter=20, nu=0.2, q=0.8; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.2, q=0.8; total time=   1.2s
# [CV] END ............................nIter=20, nu=0.2, q=0.8; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.2, q=0.8; total time=   1.0s
# [CV] END ............................nIter=20, nu=0.2, q=0.8; total time=   1.0s
# [CV] END ............................nIter=20, nu=0.2, q=0.9; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.2, q=0.9; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.2, q=0.9; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.2, q=0.9; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.2, q=0.9; total time=   1.1s
# [CV] END ..............................nIter=20, nu=0.2, q=1; total time=   1.2s
# [CV] END ..............................nIter=20, nu=0.2, q=1; total time=   1.4s
# [CV] END ..............................nIter=20, nu=0.2, q=1; total time=   1.3s
# [CV] END ..............................nIter=20, nu=0.2, q=1; total time=   1.2s
# [CV] END ..............................nIter=20, nu=0.2, q=1; total time=   1.2s
# [CV] END ............................nIter=20, nu=0.3, q=0.6; total time=   0.6s
# [CV] END ............................nIter=20, nu=0.3, q=0.6; total time=   0.6s
# [CV] END ............................nIter=20, nu=0.3, q=0.6; total time=   0.6s
# [CV] END ............................nIter=20, nu=0.3, q=0.6; total time=   0.6s
# [CV] END ............................nIter=20, nu=0.3, q=0.6; total time=   0.7s
# [CV] END ............................nIter=20, nu=0.3, q=0.7; total time=   0.7s
# [CV] END ............................nIter=20, nu=0.3, q=0.7; total time=   0.8s
# [CV] END ............................nIter=20, nu=0.3, q=0.7; total time=   0.7s
# [CV] END ............................nIter=20, nu=0.3, q=0.7; total time=   0.7s
# [CV] END ............................nIter=20, nu=0.3, q=0.7; total time=   0.7s
# [CV] END ............................nIter=20, nu=0.3, q=0.8; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.3, q=0.8; total time=   0.9s
# [CV] END ............................nIter=20, nu=0.3, q=0.8; total time=   1.0s
# [CV] END ............................nIter=20, nu=0.3, q=0.8; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.3, q=0.8; total time=   1.0s
# [CV] END ............................nIter=20, nu=0.3, q=0.9; total time=   1.1s
# [CV] END ............................nIter=20, nu=0.3, q=0.9; total time=   1.2s
# [CV] END ............................nIter=20, nu=0.3, q=0.9; total time=   1.3s
# [CV] END ............................nIter=20, nu=0.3, q=0.9; total time=   1.2s
# [CV] END ............................nIter=20, nu=0.3, q=0.9; total time=   1.1s
# [CV] END ..............................nIter=20, nu=0.3, q=1; total time=   1.5s
# [CV] END ..............................nIter=20, nu=0.3, q=1; total time=   1.3s
# [CV] END ..............................nIter=20, nu=0.3, q=1; total time=   1.4s
# [CV] END ..............................nIter=20, nu=0.3, q=1; total time=   1.3s
# [CV] END ..............................nIter=20, nu=0.3, q=1; total time=   1.4s
# [CV] END ............................nIter=30, nu=0.1, q=0.6; total time=   1.2s
# [CV] END ............................nIter=30, nu=0.1, q=0.6; total time=   1.2s
# [CV] END ............................nIter=30, nu=0.1, q=0.6; total time=   1.2s
# [CV] END ............................nIter=30, nu=0.1, q=0.6; total time=   1.3s
# [CV] END ............................nIter=30, nu=0.1, q=0.6; total time=   1.5s
# [CV] END ............................nIter=30, nu=0.1, q=0.7; total time=   1.4s
# [CV] END ............................nIter=30, nu=0.1, q=0.7; total time=   1.1s
# [CV] END ............................nIter=30, nu=0.1, q=0.7; total time=   1.1s
# [CV] END ............................nIter=30, nu=0.1, q=0.7; total time=   1.2s
# [CV] END ............................nIter=30, nu=0.1, q=0.7; total time=   1.1s
# [CV] END ............................nIter=30, nu=0.1, q=0.8; total time=   1.4s
# [CV] END ............................nIter=30, nu=0.1, q=0.8; total time=   1.4s
# [CV] END ............................nIter=30, nu=0.1, q=0.8; total time=   1.5s
# [CV] END ............................nIter=30, nu=0.1, q=0.8; total time=   1.6s
# [CV] END ............................nIter=30, nu=0.1, q=0.8; total time=   1.6s
# [CV] END ............................nIter=30, nu=0.1, q=0.9; total time=   1.8s
# [CV] END ............................nIter=30, nu=0.1, q=0.9; total time=   1.6s
# [CV] END ............................nIter=30, nu=0.1, q=0.9; total time=   1.7s
# [CV] END ............................nIter=30, nu=0.1, q=0.9; total time=   1.7s
# [CV] END ............................nIter=30, nu=0.1, q=0.9; total time=   1.7s
# [CV] END ..............................nIter=30, nu=0.1, q=1; total time=   1.4s
# [CV] END ..............................nIter=30, nu=0.1, q=1; total time=   1.4s
# [CV] END ..............................nIter=30, nu=0.1, q=1; total time=   1.4s
# [CV] END ..............................nIter=30, nu=0.1, q=1; total time=   1.4s
# [CV] END ..............................nIter=30, nu=0.1, q=1; total time=   1.5s
# [CV] END ............................nIter=30, nu=0.2, q=0.6; total time=   0.7s
# [CV] END ............................nIter=30, nu=0.2, q=0.6; total time=   1.0s
# [CV] END ............................nIter=30, nu=0.2, q=0.6; total time=   0.7s
# [CV] END ............................nIter=30, nu=0.2, q=0.6; total time=   0.7s
# [CV] END ............................nIter=30, nu=0.2, q=0.6; total time=   0.8s
# [CV] END ............................nIter=30, nu=0.2, q=0.7; total time=   0.9s
# [CV] END ............................nIter=30, nu=0.2, q=0.7; total time=   1.0s
# [CV] END ............................nIter=30, nu=0.2, q=0.7; total time=   0.9s
# [CV] END ............................nIter=30, nu=0.2, q=0.7; total time=   0.8s
# [CV] END ............................nIter=30, nu=0.2, q=0.7; total time=   0.9s
# [CV] END ............................nIter=30, nu=0.2, q=0.8; total time=   1.1s
# [CV] END ............................nIter=30, nu=0.2, q=0.8; total time=   1.1s
# [CV] END ............................nIter=30, nu=0.2, q=0.8; total time=   1.2s
# [CV] END ............................nIter=30, nu=0.2, q=0.8; total time=   1.3s
# [CV] END ............................nIter=30, nu=0.2, q=0.8; total time=   1.2s
# [CV] END ............................nIter=30, nu=0.2, q=0.9; total time=   1.6s
# [CV] END ............................nIter=30, nu=0.2, q=0.9; total time=   1.3s
# [CV] END ............................nIter=30, nu=0.2, q=0.9; total time=   1.5s
# [CV] END ............................nIter=30, nu=0.2, q=0.9; total time=   1.4s
# [CV] END ............................nIter=30, nu=0.2, q=0.9; total time=   1.3s
# [CV] END ..............................nIter=30, nu=0.2, q=1; total time=   1.5s
# [CV] END ..............................nIter=30, nu=0.2, q=1; total time=   1.5s
# [CV] END ..............................nIter=30, nu=0.2, q=1; total time=   1.5s
# [CV] END ..............................nIter=30, nu=0.2, q=1; total time=   1.7s
# [CV] END ..............................nIter=30, nu=0.2, q=1; total time=   1.6s
# [CV] END ............................nIter=30, nu=0.3, q=0.6; total time=   0.7s
# [CV] END ............................nIter=30, nu=0.3, q=0.6; total time=   0.6s
# [CV] END ............................nIter=30, nu=0.3, q=0.6; total time=   0.8s
# [CV] END ............................nIter=30, nu=0.3, q=0.6; total time=   0.7s
# [CV] END ............................nIter=30, nu=0.3, q=0.6; total time=   0.8s
# [CV] END ............................nIter=30, nu=0.3, q=0.7; total time=   0.8s
# [CV] END ............................nIter=30, nu=0.3, q=0.7; total time=   0.9s
# [CV] END ............................nIter=30, nu=0.3, q=0.7; total time=   1.0s
# [CV] END ............................nIter=30, nu=0.3, q=0.7; total time=   0.9s
# [CV] END ............................nIter=30, nu=0.3, q=0.7; total time=   0.9s
# [CV] END ............................nIter=30, nu=0.3, q=0.8; total time=   1.4s
# [CV] END ............................nIter=30, nu=0.3, q=0.8; total time=   1.2s
# [CV] END ............................nIter=30, nu=0.3, q=0.8; total time=   1.2s
# [CV] END ............................nIter=30, nu=0.3, q=0.8; total time=   1.2s
# [CV] END ............................nIter=30, nu=0.3, q=0.8; total time=   1.2s
# [CV] END ............................nIter=30, nu=0.3, q=0.9; total time=   1.6s
# [CV] END ............................nIter=30, nu=0.3, q=0.9; total time=   1.6s
# [CV] END ............................nIter=30, nu=0.3, q=0.9; total time=   1.7s
# [CV] END ............................nIter=30, nu=0.3, q=0.9; total time=   1.7s
# [CV] END ............................nIter=30, nu=0.3, q=0.9; total time=   1.4s
# [CV] END ..............................nIter=30, nu=0.3, q=1; total time=   1.7s
# [CV] END ..............................nIter=30, nu=0.3, q=1; total time=   2.1s
# [CV] END ..............................nIter=30, nu=0.3, q=1; total time=   2.4s
# [CV] END ..............................nIter=30, nu=0.3, q=1; total time=   2.2s
# [CV] END ..............................nIter=30, nu=0.3, q=1; total time=   2.0s

# %%
model = SGTB(nIter=10, q=1, nu=0.1, md=3)
model.fit(trainx, trainy)

# %%
model.train_dict
# Out:
# {0: 108.92755893242877,
#  1: 107.00816515931476,
#  2: 105.41839736065984,
#  3: 104.11700703718701,
#  4: 102.99433756310896,
#  5: 102.06346437786978,
#  6: 101.25878496182132,
#  7: 100.50078704566681,
#  8: 99.84163918201607,
#  9: 99.2509366993107}
